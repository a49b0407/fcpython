# %%
import seaborn as sns
import pandas as pd
sns.set(style='ticks')
data = pd.read_csv('salary.csv')[:1000]
sns.relplot(data=data,x='Salary',y='Age',hue='Education',style='Education',col='Gender')

# %%
data
# Out:
#      Unnamed: 0       District    Salary  Age        English  \
# 0             0       Brooklyn  120000.0   31  Only language
# 1             1       Brooklyn   45000.0   28  Only language
# 2             2      Manhatten   85000.0   54  Only language
# 3             3      Manhatten   12000.0   45  Only language
# 4             4       Brooklyn       0.0   75      Very well
# ..          ...            ...       ...  ...            ...
# 995         995         Queens   21000.0   42       Not well
# 996         996         Queens       0.0   40     Not at all
# 997         997         Queens       0.0   16     Not at all
# 998         998  Staten Island       0.0   70      Very well
# 999         999  Staten Island   30000.0   29  Only language
#
#                Education  Gender
# 0        Academic degree    Male
# 1        Academic degree  Female
# 2        Academic degree    Male
# 3    High school diploma  Female
# 4        Academic degree  Female
# ..                   ...     ...
# 995      Academic degree    Male
# 996  High school diploma  Female
# 997           No diploma  Female
# 998      Academic degree  Female
# 999      Academic degree    Male
#
# [1000 rows x 7 columns]
